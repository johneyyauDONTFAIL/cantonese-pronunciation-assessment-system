# %%
import os

if not os.path.exists('cantonese-pronunciation-assessment-system'):
  # !git clone https://github.com/johneyyauDONTFAIL/cantonese-pronunciation-assessment-system.git
# %cd cantonese-pronunciation-assessment-system
# !pip install -r requirements.txt

# %%
# %cd /content/cantonese-pronunciation-assessment-system/
# The first time inference will take longer time as it need to load the model
# !python inference.py "./audio/城大.wav" "城大"
